# %% [markdown]
# ## 作業一
# #### 學生混合學習的表現數據：xAPI-Educational Mining Dataset

# %% [markdown]
#     1.此資料集是一個完整的課程期間，函有廣泛的資料足以探討學生在自主學習時的多方因素之間的關係。
#         (1).基本類別信息
#         (2).學生量化成績
#         (3).學生實體課堂參與行為
#         (4).學生線上課程參與行為
#         (5).學生家長反饋
#     2.資料來源自約翰大學的一位IbrahimAljarah教授透過學習管理系統(LMS)收集。
#     3.資料為結構化資料。
#     4.本資料集無特別要求方案或建立競賽，可進行探索性分析了解內部關係。

# %% [markdown]
# ## 作業二

# %% [markdown]
#     1.問題假設：針對在尖峰時段的高頻客戶提供折扣並提高服務品質是否可以增加車隊的總收益？
#     2.用來解決問題要分析的數據：
#         (1).列出三年內該時段的每一筆交易，排序每位用戶的交易次數多寡並取前80%列為高頻用戶，並紀錄尖峰時段內每個高頻用戶的交易時間點。
#         (2).依照高頻用戶的上下車地點統計出數個彼此鄰近的熱門上車點，在車點之間的以該時段為基準規劃最佳路線圖作為標準路線。
#         (3).數據來源：與顧客交易的mobile app 或 車體聯網的servers。
#     3.結構化資料
#     4.1.解決方案：
#         (1).針對時段內的高頻用戶提出高階車種優惠、以及即時打車提醒。
#         (2).減少該時段內塞車時間與空車量。
#     4.2.驗證方式
#         操作隨機對照實驗

# %% [markdown]
# ## 作業三
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y1,y2):
    """
    實際值：y1
    預測值：y2
    mse:MSE
    """
    mse = sum(y1-y2)**2 / len(y1)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 222.482
